# %%
str1 = 'Data SCIence'
print(str1)
print(id(str1))
# Out:
# Data SCIence
# 1398839428912

# %% [markdown]
# #### Lower

# %%
lower_str1 = str1.lower()
print(lower_str1)
print(id(lower_str1))
# Out:
# data science
# 1398839452400

# %% [markdown]
# #### Upper

# %%
upper_str1 = str1.upper()
print(upper_str1)
print(id(upper_str1))
# Out:
# DATA SCIENCE
# 1398839484784

# %%
str2 = "This is 123 abc"

# %%
print(str2.lower())
print(str2.upper())
# Out:
# this is 123 abc
# THIS IS 123 ABC

# %% [markdown]
# #### Strip

# %%
str3 = "    data science   "
str3.strip() ### strip method will remove empty white spaces
# Out:
# 'data science'

# %%
str4 = '#####data science###########'
str4.strip('#')
# Out:
# 'data science'

# %%
str4 = '$$$$$$$$$$#####data science###########@@@@@@@@@@@@'
str4.strip('$').strip('#')
# Out:
# 'data science###########@@@@@@@@@@@@'

# %%
str4 = '$$$$$$$$$$#####data science###########@@@@@@@@@@@@'
str4.strip('$').strip('@')
# Out:
# '#####data science###########'

# %%
str4 = '$$$$$$$$$$#####data science###########@@@@@@@@@@@@'
str4.strip('$').strip('@').strip('#')
# Out:
# 'data science'

# %% [markdown]
# #### Replace

# %%
str1
# Out:
# 'Data SCIence'

# %%
str1.replace('SCIence','analysis')
# Out:
# 'Data analysis'

# %%
str1.replace('a','z')
# Out:
# 'Dztz SCIence'

# %%
str6 = 'Data Science and Data Engineering'
str6
# Out:
# 'Data Science and Data Engineering'

# %%
str6.replace('Data','data', 1)
# Out:
# 'data Science and Data Engineering'

# %%
str6.replace('Data','data', 2)
# Out:
# 'data Science and data Engineering'

# %% [markdown]
# #### Split

# %%
str6.split()
# Out:
# ['Data', 'Science', 'and', 'Data', 'Engineering']

# %%
type(str6),type(str6.split())
# Out:
# (str, list)

# %%
str7 = 'Data-Science-and-Data-Engineering'
str7
# Out:
# 'Data-Science-and-Data-Engineering'

# %%
str7.split('-')
# Out:
# ['Data', 'Science', 'and', 'Data', 'Engineering']

# %%
str6
# Out:
# 'Data Science and Data Engineering'

# %%
str6.split('Data')
# Out:
# ['', ' Science and ', ' Engineering']

# %%
str7.split('-', 2)
# Out:
# ['Data', 'Science', 'and-Data-Engineering']

# %%
name = 'Mr. James Anderson'
name.split()
# Out:
# ['Mr.', 'James', 'Anderson']

# %%
name.split(maxsplit=1)
# Out:
# ['Mr.', 'James Anderson']

# %%
sal, full_name = name.split(maxsplit=1)
print(sal)
print(full_name)
# Out:
# Mr.
# James Anderson

# %% [markdown]
# #### Join

# %%
list1 = ['My','Name','is','Jack']
list1
# Out:
# ['My', 'Name', 'is', 'Jack']

# %%
' '.join(list1)
# Out:
# 'My Name is Jack'

# %%
'--'.join(list1)
# Out:
# 'My--Name--is--Jack'

# %%
'='.join(list1)
# Out:
# 'My=Name=is=Jack'

# %%
'  '.join(list1)
# Out:
# 'My  Name  is  Jack'

# %%
' 123 '.join(list1)
# Out:
# 'My 123 Name 123 is 123 Jack'

# %% [markdown]
# #### Title

# %%
str8 = 'this is the data science'
str8.title()
# Out:
# 'This Is The Data Science'

# %%
name = 'james anderson'
name.title()
# Out:
# 'James Anderson'

# %% [markdown]
# #### CApitalize

# %%
str8.capitalize()
# Out:
# 'This is the data science'

# %% [markdown]
# #### Swapcase

# %%
str8.swapcase()
# Out:
# 'THIS IS THE DATA SCIENCE'

# %% [markdown]
# #### Whitespace Handling

# %%
str10 = '       this is the data science       '
str10
# Out:
# '       this is the data science       '

# %%
str10.strip()
# Out:
# 'this is the data science'

# %% [markdown]
# ##### Lstrip

# %%
str10.lstrip()
# Out:
# 'this is the data science       '

# %% [markdown]
# #### Rstrip

# %%
str10.rstrip()
# Out:
# '       this is the data science'

# %% [markdown]
# #### Searching and Finding

# %% [markdown]
# #### Find

# %%
str10.find('data')
# Out:
# 19

# %%
str10[19]
# Out:
# 'd'

# %%
str10.find('ML') ### -1 for absence of substring
# Out:
# -1

# %%
str10.index('d')
# Out:
# 19

# %%
str10.index('ML')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 str10.index('ML')
#
# ValueError: substring not found

# %% [markdown]
# #### startswith

# %%
str10.startswith('this')
# Out:
# False

# %%
str10.startswith(' ')
# Out:
# True

# %%
str10.startswith('              ')
# Out:
# False

# %% [markdown]
# #### Endswith

# %%
str10
# Out:
# '       this is the data science       '

# %%
str10.endswith(' ')
# Out:
# True

# %% [markdown]
# #### Validation checks

# %%
str11 = '1234'

# %% [markdown]
# #### isdigit

# %%
str11.isdigit()
# Out:
# True

# %%
'123 abc'.isdigit()
# Out:
# False

# %% [markdown]
# #### isalpha

# %%
'abcd'.isalpha()
# Out:
# True

# %%
'abcd ABCD'.isalpha()
# Out:
# False

# %%
'abcdABCD'.isalpha()
# Out:
# True

# %%
'abcd124'.isalpha()
# Out:
# False

# %% [markdown]
# #### isalnum

# %%
'abcd123'.isalnum()
# Out:
# True

# %% [markdown]
# #### islower

# %%
'abcd'.islower()
# Out:
# True

# %%
'Aabcd'.islower()
# Out:
# False

# %% [markdown]
# #### isupper

# %%
'abcd'.isupper()
# Out:
# False

# %%
'ABCDEF'.isupper()
# Out:
# True

# %% [markdown]
# #### Isspace

# %%
'abc '.isspace()
# Out:
# False

# %%
'   '.isspace()
# Out:
# True

# %%
str10
# Out:
# '       this is the data science       '

# %% [markdown]
# #### Counting and measuring

# %%
print(len(str10))
print(str10)
# Out:
# 38
#        this is the data science

# %%
str10.count('data')
# Out:
# 1

# %% [markdown]
# ### String Comparison

# %% [markdown]
# #### Lexicographically

# %%
str1 = 'bannana'
str2 = 'banned'

# %%
ord('a'), ord('n')
# Out:
# (97, 110)

# %%
str2 >= str1
# Out:
# True

# %%
str2 < str1
# Out:
# False
